# %% [markdown]
# # Python SQL Tutorial
#
# In this notebook, we will show you how to use Fugue SQL to work with SQL in a python environment. Fugue SQL is a SQL engine that can run on Spark, Dask, Ray, and Pandas. It is a SQL engine that is designed for data scientists and engineers and to be easy to use.
# It also allows us to convert a Jupyter code cell into a SQL cell with the jupyter magic command ```%%fsql```.
#
# DuckDB is an in-process SQL OLAP database management system. The speed is very good on even gigabytes of data on local machines. Fugue has a deep integration with DuckDB. Fugue not only uses DuckDB as the SQL engine, but also implemented all execution engine methods using DuckDB SQL and relations. So in most part of the workflow, the data tables are kept in DuckDB and in rare cases the tables will be materialized and converted to arrow dataframes.
#
# In this notebook you will learn how to create tables and insert data into the created tables.

# %%
import os
import duckdb
import pandas as pd
import sqlalchemy
import json
from fugue_notebook import setup
import fugue_duckdb

setup()

# %% [markdown]
# We have two csv files in our data directory:
# - raw_orders.csv
# - raw_payments.csv
#
# and a json file:
# - raw_customers.json
#
#
# We will use pandas to load the data first:

# %%
df_customers = pd.read_json('data/raw_customers.json', orient='records', lines=True)
df_customers.head()
# Out:
#    id first_name last_name
# 0   1    Michael        P.
# 1   2      Shawn        M.
# 2   3   Kathleen        P.
# 3   4      Jimmy        C.
# 4   5  Katherine        R.

# %%
df_orders = pd.read_csv('data/raw_orders.csv')
df_orders.head()
# Out:
#    id  user_id  order_date     status
# 0   1        1  2018-01-01   returned
# 1   2        3  2018-01-02  completed
# 2   3       94  2018-01-04  completed
# 3   4       50  2018-01-05  completed
# 4   5       64  2018-01-05  completed

# %%
df_payment = pd.read_csv('data/raw_payments.csv')
df_payment.head()
# Out:
#    id  order_id payment_method  amount
# 0   1         1    credit_card    1000
# 1   2         2    credit_card    2000
# 2   3         3         coupon     100
# 3   4         4         coupon    2500
# 4   5         5  bank_transfer    1700

# %% [markdown]
# But we could do the same with fugue. With ```%%fsql``` we can convert the cell into a SQL cell and use fugue SQL to query the data. ```duck```  is the name of the execution engine which is DuckDB in our case.
#
# With ```LOAD``` we can import our data and save it in a variable. We can use the variable name to query the data.

# %%
# %%fsql duck
#
# raw_customers = LOAD "data/raw_customers.json"
#
# SELECT * FROM raw_customers
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id:long</th>
#       <th>first_name:str</th>
#       <th>last_name:str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Michael</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Shawn</td>
#       <td>M.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Jimmy</td>
#       <td>C.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Katherine</td>
#       <td>R.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Sarah</td>
#       <td>R.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Martin</td>
#       <td>M.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Frank</td>
#       <td>R.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>Jennifer</td>
#       <td>F.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>Henry</td>
#       <td>W.</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">DuckDataFrame: id:long,first_name:str,last_name:str</font>

# %% [markdown]
# As you can see you can load the data from various sources like csv, json, parquet, etc. and you can also load data from a database.

# %%
# %%fsql duck
#
# raw_orders = LOAD "data/raw_orders.csv" (header = "true")
#
# SELECT * FROM raw_orders
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id:str</th>
#       <th>user_id:str</th>
#       <th>order_date:str</th>
#       <th>status:str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>2018-01-01</td>
#       <td>returned</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>3</td>
#       <td>2018-01-02</td>
#       <td>completed</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>94</td>
#       <td>2018-01-04</td>
#       <td>completed</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>50</td>
#       <td>2018-01-05</td>
#       <td>completed</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>64</td>
#       <td>2018-01-05</td>
#       <td>completed</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>54</td>
#       <td>2018-01-07</td>
#       <td>completed</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>88</td>
#       <td>2018-01-09</td>
#       <td>completed</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>2</td>
#       <td>2018-01-11</td>
#       <td>returned</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>53</td>
#       <td>2018-01-12</td>
#       <td>completed</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>7</td>
#       <td>2018-01-14</td>
#       <td>completed</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">DuckDataFrame: id:str,user_id:str,order_date:str,status:str</font>

# %%
# %%fsql duck
#
# raw_payments = LOAD "data/raw_payments.csv" (header = "true")
#
# SELECT * FROM raw_payments
#
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id:str</th>
#       <th>order_id:str</th>
#       <th>payment_method:str</th>
#       <th>amount:str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>credit_card</td>
#       <td>1000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>2</td>
#       <td>credit_card</td>
#       <td>2000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>3</td>
#       <td>coupon</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>4</td>
#       <td>coupon</td>
#       <td>2500</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>5</td>
#       <td>bank_transfer</td>
#       <td>1700</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>6</td>
#       <td>credit_card</td>
#       <td>600</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>7</td>
#       <td>credit_card</td>
#       <td>1600</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>8</td>
#       <td>credit_card</td>
#       <td>2300</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>9</td>
#       <td>gift_card</td>
#       <td>2300</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>9</td>
#       <td>bank_transfer</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">DuckDataFrame: id:str,order_id:str,payment_method:str,amount:str</font>

# %% [markdown]
# Now we can have a look at some questions. For example the RFM (Recency, Frequency, and Monetary) questions that are relevant for analysing customer behaviour. Here we can either load the data again with fugue or combine pandas and fugue and use fugue on top of pandas dataframes.
#
# - When did the customers last purchase?

# %% [markdown]
# First we will join the orders and the customers table to get the customers name and the order date in one table and save it with ```YIELD``` in a dataframe ```df1``` that we can also use outside of this cell.
#
# There are also ways to save the data in a database or as a files with ```SAVE```.

# %%
# %%fsql
#
# SELECT o.user_id, o.order_date, c.first_name, c.last_name FROM df_orders AS o
# JOIN df_customers AS c
# ON o.user_id = c.id
# YIELD DATAFRAME AS df1
#
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id:long</th>
#       <th>order_date:str</th>
#       <th>first_name:str</th>
#       <th>last_name:str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2018-01-01</td>
#       <td>Michael</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2018-02-10</td>
#       <td>Michael</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>2018-01-02</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>2018-01-27</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>2018-03-11</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>94</td>
#       <td>2018-01-04</td>
#       <td>Gregory</td>
#       <td>H.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>94</td>
#       <td>2018-01-29</td>
#       <td>Gregory</td>
#       <td>H.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>50</td>
#       <td>2018-01-05</td>
#       <td>Billy</td>
#       <td>L.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>50</td>
#       <td>2018-02-20</td>
#       <td>Billy</td>
#       <td>L.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>64</td>
#       <td>2018-01-05</td>
#       <td>David</td>
#       <td>C.</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">PandasDataFrame: user_id:long,order_date:str,first_name:str,last_name:str</font>

# %% [markdown]
# Now we can write a python function that we can use with fugue in SQL. For that we have to define the schema first. Here we will use everything so we will use the ```*``` to select all columns. The schema is defined with a comment before the function.

# %%
#schema: *
def get_latest_order_date_per_customer(df: pd.DataFrame) -> pd.DataFrame:
    return df.sort_values('order_date', ascending=False).groupby('user_id').first().reset_index()

# %% [markdown]
# This python function will return the maximum date of the order date column. And can be used now in a fugue SQL query. For that we will use the ```TRANSFORM``` command. This command will apply the function to the dataframe. The function we want to use is defined by the ```USING``` command. The result will be saved in a new dataframe ```df2```.

# %%
# %%fsql duck
#
# df2 = TRANSFORM df1 USING get_latest_order_date_per_customer
# YIELD DATAFRAME AS df2
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id:long</th>
#       <th>order_date:str</th>
#       <th>first_name:str</th>
#       <th>last_name:str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2018-02-10</td>
#       <td>Michael</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>2018-01-11</td>
#       <td>Shawn</td>
#       <td>M.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>2018-03-11</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>2018-02-19</td>
#       <td>Sarah</td>
#       <td>R.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7</td>
#       <td>2018-01-14</td>
#       <td>Martin</td>
#       <td>M.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>8</td>
#       <td>2018-03-12</td>
#       <td>Frank</td>
#       <td>R.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>9</td>
#       <td>2018-03-17</td>
#       <td>Jennifer</td>
#       <td>F.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>11</td>
#       <td>2018-03-23</td>
#       <td>Fred</td>
#       <td>S.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>12</td>
#       <td>2018-03-03</td>
#       <td>Amy</td>
#       <td>D.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>13</td>
#       <td>2018-03-07</td>
#       <td>Kathleen</td>
#       <td>M.</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">PandasDataFrame: user_id:long,order_date:str,first_name:str,last_name:str</font>

# %% [markdown]
# This Dataframe ```df2``` can than also be used again as a pandas DataFrame:

# %%
df2.head(5)
# Out:
# PandasDataFrame

# %% [markdown]
# ## Exercise 1
#
# -  What is the customer recency in days?
#
# The answer to this question you can get from the previous table, by getting the date difference. Do this as an exercise.

# %%
from datetime import datetime

#schema: *, recency:int
def calculate_recency(df: pd.DataFrame) -> pd.DataFrame:
    df['recency'] = df['order_date'].apply(lambda x: (datetime.now() - datetime.strptime(x, "%Y-%m-%d")).days)
    return df

# %%
# %%fsql
#
# df_recency = TRANSFORM df2 USING calculate_recency
# YIELD DATAFRAME AS df_recency
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id:long</th>
#       <th>order_date:str</th>
#       <th>first_name:str</th>
#       <th>last_name:str</th>
#       <th>recency:int</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2018-02-10</td>
#       <td>Michael</td>
#       <td>P.</td>
#       <td>2074</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>2018-01-11</td>
#       <td>Shawn</td>
#       <td>M.</td>
#       <td>2104</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>2018-03-11</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#       <td>2045</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>2018-02-19</td>
#       <td>Sarah</td>
#       <td>R.</td>
#       <td>2065</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7</td>
#       <td>2018-01-14</td>
#       <td>Martin</td>
#       <td>M.</td>
#       <td>2101</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>8</td>
#       <td>2018-03-12</td>
#       <td>Frank</td>
#       <td>R.</td>
#       <td>2044</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>9</td>
#       <td>2018-03-17</td>
#       <td>Jennifer</td>
#       <td>F.</td>
#       <td>2039</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>11</td>
#       <td>2018-03-23</td>
#       <td>Fred</td>
#       <td>S.</td>
#       <td>2033</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>12</td>
#       <td>2018-03-03</td>
#       <td>Amy</td>
#       <td>D.</td>
#       <td>2053</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>13</td>
#       <td>2018-03-07</td>
#       <td>Kathleen</td>
#       <td>M.</td>
#       <td>2049</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">PandasDataFrame: user_id:long,order_date:str,first_name:str,last_name:str,recency:int</font>

# %% [markdown]
# The recency is quite large because the data is from 2018 ;)

# %% [markdown]
# -  How much did they spend?
#
# To answer this question let us join all 3 tables together and save it in a dataframe ```df3```.
#
# Additionally let's save the joined table as a parquet file for possible future use. Also we will see here that we can use global variables inside of fugue sql cells if we use double curly brackets ```{{}}``` around them.

# %%
PATH = os.path.join(os.getcwd())

# %%
# %%fsql
#
# SELECT o.user_id, c.first_name, c.last_name, p.amount FROM df_orders AS o
# JOIN df_customers AS c
# ON o.user_id = c.id
# JOIN df_payment AS p
# ON o.id = p.order_id
# YIELD DATAFRAME AS df3
#
# SAVE OVERWRITE "{{PATH}}/data/joined_data.parquet"
#
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id:long</th>
#       <th>first_name:str</th>
#       <th>last_name:str</th>
#       <th>amount:long</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Michael</td>
#       <td>P.</td>
#       <td>1000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Michael</td>
#       <td>P.</td>
#       <td>2300</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#       <td>2000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#       <td>2600</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#       <td>1900</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>94</td>
#       <td>Gregory</td>
#       <td>H.</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>94</td>
#       <td>Gregory</td>
#       <td>H.</td>
#       <td>2300</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>50</td>
#       <td>Billy</td>
#       <td>L.</td>
#       <td>2500</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>50</td>
#       <td>Billy</td>
#       <td>L.</td>
#       <td>2200</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>64</td>
#       <td>David</td>
#       <td>C.</td>
#       <td>1700</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">PandasDataFrame: user_id:long,first_name:str,last_name:str,amount:long</font>

# %% [markdown]
# And now we can simply sum about the amount per customer:

# %%
# %%fsql duck
#
# SELECT first_name, last_name, SUM(amount) FROM df3
# GROUP BY first_name, last_name
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>first_name:str</th>
#       <th>last_name:str</th>
#       <th>`sum(amount)`:long</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Michael</td>
#       <td>P.</td>
#       <td>3300</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>David</td>
#       <td>C.</td>
#       <td>3000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Victor</td>
#       <td>H.</td>
#       <td>2400</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Amanda</td>
#       <td>H.</td>
#       <td>1200</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Adam</td>
#       <td>W.</td>
#       <td>3900</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Fred</td>
#       <td>S.</td>
#       <td>300</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Todd</td>
#       <td>W.</td>
#       <td>2900</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Willie</td>
#       <td>H.</td>
#       <td>2200</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Billy</td>
#       <td>L.</td>
#       <td>4700</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Rose</td>
#       <td>M.</td>
#       <td>5700</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">DuckDataFrame: first_name:str,last_name:str,`sum(amount)`:long</font>

# %% [markdown]
# ## Exercise 2
#
# Now you can try and answer the next questions as an exercise either you can write a python function that you apply with ```TRANSFORM``` or you can use the SQL to answer the questions.
#
# - What is the most common payment method?

# %%
# %%fsql
#
# SELECT  p.payment_method, COUNT(*) AS method_count FROM df_payment AS p
# GROUP BY p.payment_method
# ORDER BY method_count DESC
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>payment_method:str</th>
#       <th>method_count:long</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>credit_card</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>bank_transfer</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>coupon</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>gift_card</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">PandasDataFrame: payment_method:str,method_count:long</font>

# %% [markdown]
# With python function and fugue's transform:

# %%
#schema: payment_method:str, count:int
def count_payment_methods(df: pd.DataFrame) -> pd.DataFrame:
    df = df['payment_method'].value_counts().reset_index()
    return df

# %%
# %%fsql duck
#
# df_payment_method_count = TRANSFORM df_payment USING count_payment_methods
#
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>payment_method:str</th>
#       <th>count:int</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>credit_card</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bank_transfer</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>coupon</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>gift_card</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">PandasDataFrame: payment_method:str,count:int</font>

# %% [markdown]
# ## Exercise 3
#
# - Create a table that includes the aggregated data from the questions above!

# %%
# %%fsql
#
# SELECT  df2.user_id,
#         df2.first_name,
#         df2.last_name,
#         df2.order_date,
#         df3.amount,
#         df_recency.recency
# FROM df2
# JOIN df3 ON df3.user_id = df2.user_id
# JOIN df_recency ON df_recency.user_id = df2.user_id
#
# PRINT
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id:long</th>
#       <th>first_name:str</th>
#       <th>last_name:str</th>
#       <th>order_date:str</th>
#       <th>amount:long</th>
#       <th>recency:int</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Michael</td>
#       <td>P.</td>
#       <td>2018-02-10</td>
#       <td>1000</td>
#       <td>2074</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Michael</td>
#       <td>P.</td>
#       <td>2018-02-10</td>
#       <td>2300</td>
#       <td>2074</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Shawn</td>
#       <td>M.</td>
#       <td>2018-01-11</td>
#       <td>2300</td>
#       <td>2104</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#       <td>2018-03-11</td>
#       <td>2000</td>
#       <td>2045</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#       <td>2018-03-11</td>
#       <td>2600</td>
#       <td>2045</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>Kathleen</td>
#       <td>P.</td>
#       <td>2018-03-11</td>
#       <td>1900</td>
#       <td>2045</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>Sarah</td>
#       <td>R.</td>
#       <td>2018-02-19</td>
#       <td>800</td>
#       <td>2065</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>Martin</td>
#       <td>M.</td>
#       <td>2018-01-14</td>
#       <td>2600</td>
#       <td>2101</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>Frank</td>
#       <td>R.</td>
#       <td>2018-03-12</td>
#       <td>1900</td>
#       <td>2044</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>8</td>
#       <td>Frank</td>
#       <td>R.</td>
#       <td>2018-03-12</td>
#       <td>2600</td>
#       <td>2044</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <font size="-1">PandasDataFrame: user_id:long,first_name:str,last_name:str,order_date:str,amount:long,recency:int</font>
